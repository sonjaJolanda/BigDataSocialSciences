# %% [markdown]
# # Week 15: additional material
# ## data visualization: seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %% [markdown]
# Let's first try to make a barplot. <br>
# Before that, we will learn about setting theme for sns.

# %%
sns.set_theme(style='dark')
sns.barplot(data=tips, x='smoker', y='total_bill')
# Out:
# <AxesSubplot: xlabel='smoker', ylabel='total_bill'>

# %%
sns.barplot(data=tips, x='smoker', y='total_bill', hue='sex', palette='Pastel2')
# Out:
# <AxesSubplot: xlabel='smoker', ylabel='total_bill'>

# %% [markdown]
# Then, let's try making a boxplot

# %%
sns.boxplot(x='day', y='total_bill', data=tips, palette='bright')
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# I want to differentiate between smokers and non-smokers. <br>

# %%
sns.boxplot(x='day', y='total_bill', data=tips, palette='bright', hue='smoker')
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# Swarmplots

# %%
sns.swarmplot(data=tips, x='day', y='total_bill', hue='smoker')
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# Horizontally?

# %%
sns.swarmplot(data=tips, y='day', x='total_bill', hue='smoker')
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='day'>

# %% [markdown]
# Scatterplot <br>
# Two ways to make it. <br>
# 1. relplot
# 2. scatterplot

# %%
plt.figure(figsize=(10,5))
sns.relplot(data=tips, x='total_bill', y='tip', hue='day', size='size')

# %%
plt.figure(figsize=(10,5))
sns.relplot(data=tips, x='total_bill', y='tip', hue='day', size='size', palette='rocket')

# %% [markdown]
# LMplot

# %%
sns.set_style('darkgrid')
sns.lmplot(x='total_bill', y='tip', hue='smoker', data=tips)

# %% [markdown]
# Let's use dataset on penguins

# %%
penguins = sns.load_dataset('penguins')

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...
